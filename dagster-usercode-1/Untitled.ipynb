# %%
import pandas as pd

# %%
df = pd.read_csv("s3://anonymous@ray-example-data/iris.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/dagster-helm-demo/dagster-usercode-1/.venv/lib/python3.9/site-packages/fsspec/registry.py:242, in get_filesystem_class(protocol)
#     241 try:
# --> 242     register_implementation(protocol, _import_class(bit["class"]))
#     243 except ImportError as e:
#
# File ~/projects/dagster-helm-demo/dagster-usercode-1/.venv/lib/python3.9/site-packages/fsspec/registry.py:277, in _import_class(fqp)
#     276 is_s3 = mod == "s3fs"
# --> 277 mod = importlib.import_module(mod)
#     278 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# ...
